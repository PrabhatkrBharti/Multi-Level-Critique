# %%
import json
import numpy as np 
import pandas as pd 
import csv
import pickle
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle

# %%
## PATH TO OUR DATASET ##
PATH = 'dataset.csv' ## ADD PATH HERE
df = pd.read_csv(PATH)
df['count'] = np.ones(df.shape[0])
df = df[['Tone', 'N/C', 'count']]
df
# Out:
#       Tone  N/C  count
# 0        1  5.0    1.0
# 1        2  4.0    1.0
# 2        2  3.0    1.0
# 3        1  4.0    1.0
# 4        3  3.0    1.0
# ...    ...  ...    ...
# 2711     3  2.0    1.0
# 2712     3  4.0    1.0
# 2713     3  1.0    1.0
# 2714     1  1.0    1.0
# 2715     2  3.0    1.0
#
# [2716 rows x 3 columns]

# %%
# GROUP BY
df.groupby(['N/C', 'Tone']).count()
# Out:
#           count
# N/C Tone
# 1.0 1        77
#     2       116
#     3        70
# 2.0 1       202
#     2       277
#     3       158
# 3.0 1       320
#     2       475
#     3       270
# 4.0 1       142
#     2       243
#     3       110
# 5.0 1        77
#     2       119
#     3        59

# %%
fig, ax = plt.subplots(figsize=(15,7))
df.groupby(['N/C', 'Tone']).count().unstack().plot(kind = 'bar', ax=ax)
plt.legend(['Tone Level 1', 'Tone Level 2', 'Tone Level 3'], fontsize=16)
plt.xlabel("Levels of Constructiveness with Politeness Tone sub-levels" ,fontsize=16)
plt.ylabel("Number of Reviews", fontsize=16)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=0)
plt.show()
